# %% [markdown]
# ## Image Handling and Pixel Transformations Using OpenCV
# ## Name : Dinesh kartik R
# ## reg no: 212224230068

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('dk.jpeg', cv2.IMREAD_COLOR)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb, cmap='viridis')  # You can change 'viridis' to another cmap or use None for RGB images
plt.title("Original Image")
plt.axis('off')  # Removes axis ticks and labels
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (1600, 480, 3)

# %%
line_img = cv2.line(img_rgb, (0, 0), (768, 600), (255, 0, 0), 2) # cv2.line(image, start_point, end_point, color, thickness)

# %%
plt.imshow(line_img, cmap='viridis')  
plt.title("Image with Line")
plt.axis('off')  
plt.show()

# %%
image = cv2.imread('expp1.jpg') 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (1600, 480, 3)

# %%
circle_img = cv2.circle(img_rgb,(400,300),150,(255,0,0),10) # cv2.circle(image, center, radius, color, thickness)

# %%
plt.imshow(circle_img, cmap='viridis')  
plt.title("Image with Circle")
plt.axis('off')  
plt.show()

# %%
image = cv2.imread('Qno. 1.jpg') 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (1600, 480, 3)

# %%
rectangle_img = cv2.rectangle(img_rgb, (0, 0), (768, 600), (0, 0, 255), 10)  # cv2.rectangle(image, start_point, end_point, color, thickness)

# %%
plt.imshow(rectangle_img, cmap='viridis')  
plt.title("Image with square")
plt.axis('off')  
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
text_img = cv2.putText(img_rgb, "young seagull", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 10)  ## cv2.putText(image, text, position, font, font_scale, color, thickness)

# %%
plt.imshow(text_img, cmap='viridis')  
plt.title("Image with Text")
plt.axis('off')  
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# %%
plt.imshow(image_hsv)
plt.title("HSV Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))

# %%
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(image_gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))

# %%
image_ycrcb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# %%
plt.imshow(image_ycrcb)
plt.title("YCrCb Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))

# %%
image_hsv_to_rgb = cv2.cvtColor(image_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(image_hsv_to_rgb)
plt.title("HSV to RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))

# %%
image[200:500, 200:500] = [255, 255, 255]

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.title("Image with 300x300 White Block")
plt.axis("off")
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
image.shape
# Out:
# (1600, 480, 3)

# %%
resized_image = cv2.resize(image, (768 // 2, 600 // 2))  # (new_width, new_height)

# %%
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

# %%
resized_image_rgb.shape
# Out:
# (300, 384, 3)

# %%
plt.imshow(resized_image_rgb)
plt.title("Resized Image (Half Size)")
plt.axis("off")
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
image.shape
# Out:
# (1600, 480, 3)

# %%
roi = image[50:350, 50:350]

# %%
roi_rgb = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(roi_rgb)
plt.title("Cropped Region of Interest (ROI)")
plt.axis("off")
plt.show()

# %%
image = cv2.imread('dk.jpeg')

# %%
flipped_horizontally = cv2.flip(image, 1)

# %%
flipped_horizontally_rgb = cv2.cvtColor(flipped_horizontally, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flipped_horizontally_rgb)
plt.title("Flipped Horizontally")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))

# %%
flipped_vertically = cv2.flip(image, 0)

# %%
flipped_vertically_rgb = cv2.cvtColor(flipped_vertically, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flipped_vertically_rgb)
plt.title("Flipped Vertically")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(1599.5), np.float64(-0.5))
